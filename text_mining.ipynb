# %%
from selenium import webdriver
import sys
import time

url="https://news.naver.com/main/read.naver?m_view=1&includeAllCount=true&mode=LSD&mid=sec&sid1=102&oid=022&aid=0003348912"

driver = webdriver.Chrome("C:/chromedriver.exe")
driver.implicitly_wait(30)
driver.get(url)
#btn_more = driver.find_element_by_css_selector("span.u_cbox_page_more")
#print(btn_more.text)

#클린봇 해제
cleanbot = driver.find_element_by_css_selector('a.u_cbox_cleanbot_setbutton')
cleanbot.click()
time.sleep(1)
cleanbot_disable = driver.find_element_by_xpath("//input[@id='cleanbot_dialog_checkbox_cbox_module']")
cleanbot_disable.click()
time.sleep(1)
cleanbot_confirm = driver.find_element_by_css_selector('button.u_cbox_layer_cleanbot2_extrabtn')
cleanbot_confirm.click()
time.sleep(1)
 

while True:
    try:
        btn_more = driver.find_element_by_css_selector("span.u_cbox_page_more")
        btn_more.click()
        time.sleep(1)
    except:
        break
       
        
#댓글 추출
contents = driver.find_elements_by_css_selector('span.u_cbox_contents')
f = open("smoking_text.txt","a",encoding ="utf-8")


for content in contents:
    text = content.text
    f.write(text)

# %%
from selenium import webdriver
import sys
import time

url="https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=055&aid=0000708920&m_view=1&includeAllCount=true&m_url=%2Fcomment%2Fall.nhn%3FserviceId%3Dnews%26gno%3Dnews055%2C0000708920%26sort%3Dlikability"

driver = webdriver.Chrome("C:/chromedriver.exe")
driver.implicitly_wait(30)
driver.get(url)
#btn_more = driver.find_element_by_css_selector("span.u_cbox_page_more")
#print(btn_more.text)

#클린봇 해제
cleanbot = driver.find_element_by_css_selector('a.u_cbox_cleanbot_setbutton')
cleanbot.click()
time.sleep(1)
cleanbot_disable = driver.find_element_by_xpath("//input[@id='cleanbot_dialog_checkbox_cbox_module']")
cleanbot_disable.click()
time.sleep(1)
cleanbot_confirm = driver.find_element_by_css_selector('button.u_cbox_layer_cleanbot2_extrabtn')
cleanbot_confirm.click()
time.sleep(1)
 

while True:
    try:
        btn_more = driver.find_element_by_css_selector("span.u_cbox_page_more")
        btn_more.click()
        time.sleep(1)
    except:
        break
       
        
#댓글 추출
contents = driver.find_elements_by_css_selector('span.u_cbox_contents')
f = open("smoking_text.txt","a",encoding ="utf-8")


for content in contents:
    text = content.text
    f.write(text)

# %%
from selenium import webdriver
import sys
import time

url="https://news.naver.com/main/read.naver?m_view=1&includeAllCount=true&mode=LSD&mid=sec&sid1=102&oid=022&aid=0003348912"

driver = webdriver.Chrome("C:/chromedriver.exe")
driver.implicitly_wait(30)
driver.get(url)
#btn_more = driver.find_element_by_css_selector("span.u_cbox_page_more")
#print(btn_more.text)

#클린봇 해제
cleanbot = driver.find_element_by_css_selector('a.u_cbox_cleanbot_setbutton')
cleanbot.click()
time.sleep(1)
cleanbot_disable = driver.find_element_by_xpath("//input[@id='cleanbot_dialog_checkbox_cbox_module']")
cleanbot_disable.click()
time.sleep(1)
cleanbot_confirm = driver.find_element_by_css_selector('button.u_cbox_layer_cleanbot2_extrabtn')
cleanbot_confirm.click()
time.sleep(1)
 

while True:
    try:
        btn_more = driver.find_element_by_css_selector("span.u_cbox_page_more")
        btn_more.click()
        time.sleep(1)
    except:
        break
       
        
#댓글 추출
contents = driver.find_elements_by_css_selector('span.u_cbox_contents')
f = open("smoking_text.txt","a",encoding ="utf-8")


for content in contents:
    text = content.text
    f.write(text)
